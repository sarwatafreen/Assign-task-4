# %% [markdown]
# <a href="https://colab.research.google.com/github/sarwatafreen/Assign-task-4/blob/main/Project_5_Hangman_Python_Project%2C_provide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
print("you are lost😲")
word_list =["python","hangman","programming","computer","software","algorithm"]
chosen_word = random.choices(word_list)
guesses =[]
max_attempts =6
attempts = 0
hangman_stages = [
    """
    -----
    |   |
        |
        |
        |
    """,
    """
    -----
    |   |
    O   |
        |
        |
    """,
    """
    -----
    |   |
    O   |
    |   |
        |
    """,
    """
    -----
    |   |
    O   |
   /|\\  |
        |
    """,
    """
    -----
    |   |
    O   |
   /|\\  |
   / \\  |
    """
]
chosen_word = "python"  # Example word
guesses = []
attempts = 0
max_attempts = len(hangman_stages) - 1  # Number of hangman stages

while True:
    print(hangman_stages[attempts])  # Print the current hangman stage

    display_word = ""  # Corrected variable name
    for letter in chosen_word:
        if letter in guesses:
            display_word += letter
        else:
            display_word += "_"

    print(f"Word: {display_word}")

    if "_" not in display_word:  # Check if the user won
        print(f"Congratulations! You guessed the word: {chosen_word}")
        break

    guess = input("Guess a letter: ").lower()

    if len(guess) != 1 or not guess.isalpha():
        print("Please enter a single letter.")
        continue

    if guess in guesses:
        print("You already guessed that letter.")
        continue

    guesses.append(guess)

    if guess in chosen_word:
        print("Correct!")
    else:
        print("Wrong guess!")
        attempts += 1  # Increment attempts on wrong guess

    if attempts >= max_attempts:  # Check if the user lost
        print(f"Sorry, you ran out of attempts. The word was: {chosen_word}")
        break
# Out:
# you are lost😲
#
#     -----
#     |   |
#         |
#         |
#         |
#
# Word: ______
# Guess a letter: e
# Wrong guess!
#
#     -----
#     |   |
#     O   |
#         |
#         |
#
# Word: ______
# Guess a letter: python
# Please enter a single letter.
#
#     -----
#     |   |
#     O   |
#         |
#         |
#
# Word: ______
# Guess a letter: h
# Correct!
#
#     -----
#     |   |
#     O   |
#         |
#         |
#
# Word: ___h__
# Guess a letter: g
# Wrong guess!
#
#     -----
#     |   |
#     O   |
#     |   |
#         |
#
# Word: ___h__
# Guess a letter: p
# Correct!
#
#     -----
#     |   |
#     O   |
#     |   |
#         |
#
# Word: p__h__
# Guess a letter: y
# Correct!
#
#     -----
#     |   |
#     O   |
#     |   |
#         |
#
# Word: py_h__
# Guess a letter: t
# Correct!
#
#     -----
#     |   |
#     O   |
#     |   |
#         |
#
# Word: pyth__
# Guess a letter: o
# Correct!
#
#     -----
#     |   |
#     O   |
#     |   |
#         |
#
# ...
